# %% [markdown]
# <a href="https://colab.research.google.com/github/AnupriyaSaxena28/Case-Study-4/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

def load_tasks(filename="todo.txt"):
    """Loads tasks from a file."""
    if os.path.exists(filename):
        with open(filename, "r") as f:
            tasks = [line.strip() for line in f]
        return tasks
    return []

def save_tasks(tasks, filename="todo.txt"):
    """Saves tasks to a file."""
    with open(filename, "w") as f:
        for task in tasks:
            f.write(task + "\n")

def add_task(tasks, task):
    """Adds a task to the list."""
    tasks.append(task)
    print(f"Task '{task}' added.")

def view_tasks(tasks):
    """Displays the list of tasks."""
    if not tasks:
        print("No tasks found.")
        return
    print("Tasks:")
    for i, task in enumerate(tasks, 1):
        print(f"{i}. {task}")

def remove_task(tasks, task_index):
    """Removes a task from the list."""
    if 1 <= task_index <= len(tasks):
        removed_task = tasks.pop(task_index - 1)
        print(f"Task '{removed_task}' removed.")
    else:
        print("Invalid task number.")

def main():
    """Main function to run the to-do list application."""
    tasks = load_tasks()

    while True:
        print("\nOptions:")
        print("1. Add task")
        print("2. View tasks")
        print("3. Remove task")
        print("4. Save and exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            task = input("Enter task: ")
            add_task(tasks, task)
        elif choice == "2":
            view_tasks(tasks)
        elif choice == "3":
            view_tasks(tasks)  # Show tasks with numbers
            try:
                task_index = int(input("Enter task number to remove: "))
                remove_task(tasks, task_index)
            except ValueError:
                print("Invalid input. Please enter a number.")
        elif choice == "4":
            save_tasks(tasks)
            print("Tasks saved. Exiting.")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Options:
# 1. Add task
# 2. View tasks
# 3. Remove task
# 4. Save and exit
# Enter your choice: 1
# Enter task: Wake up early in the morning
# Task 'Wake up early in the morning' added.
#
# Options:
# 1. Add task
# 2. View tasks
# 3. Remove task
# 4. Save and exit
# Enter your choice: 1
# Enter task: Go for a walk
# Task 'Go for a walk' added.
#
# Options:
# 1. Add task
# 2. View tasks
# 3. Remove task
# 4. Save and exit
# Enter your choice: 1
# Enter task: Have a healthy breakfast
# Task 'Have a healthy breakfast' added.
#
# Options:
# 1. Add task
# 2. View tasks
# 3. Remove task
# 4. Save and exit
# Enter your choice: 2
# Tasks:
# 1. Wake up early in the morning
# 2. Go for a walk
# 3. Have a healthy breakfast
#
# Options:
# 1. Add task
# 2. View tasks
# 3. Remove task
# 4. Save and exit
# Enter your choice: 3
# Tasks:
# 1. Wake up early in the morning
# 2. Go for a walk
# 3. Have a healthy breakfast
# Enter task number to remove: 2
# Task 'Go for a walk' removed.
#
# Options:
# ...
